# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

#load dataset
data = pd.read_csv("performance_dataset.csv")

#Input & Output
X = data[["Study_Hours_per_Week"]]
y = data[" Total_Score"]

model = LinearRegression()
model.fit(X, y)
predicted_score = model.predict(X)

#Valid regression metrics
mae = mean_absolute_error(y, predicted_score)
mse = mean_squared_error(y, predicted_score)
rmse = np.sqrt(mse)
r2 = r2_score(y, predicted_score)

# show results
print("Mean Absolute Error:", round(mae, 2))
print("Mean Squared Error:", round(mse, 2))
print("Root Mean Squared Error:", round(rmse, 2))
print("R2 Score:", round(r2,2))

#histogram
plt.figure(figsize=(10, 6))
plt.hist(data[" Total_Score"], bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Total_Score")
plt.xlabel("Total_Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

#Scatter + Regression Line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='skyblue', label="Actual Scores")
plt.plot(X, predicted_score, color="red", label="Predicted Scores")
plt.title("Model Prediction VS Actual Scores")
plt.xlabel("Study Hours per week")
plt.ylabel("Final Output")
plt.grid(True)
plt.show()


new_hours = 9
predicted_new_score = model.predict(pd.DataFrame([[new_hours]], columns=["Study_Hours_per_Week"]))
print(f"Predicted Final Score for {new_hours} Hours is {predicted_new_score[0]:.2f}")
# Out:
# Mean Absolute Error: 15.26
# Mean Squared Error: 311.47
# Root Mean Squared Error: 17.65
# R2 Score: 0.0
# Predicted Final Score for 9 Hours is 70.09
